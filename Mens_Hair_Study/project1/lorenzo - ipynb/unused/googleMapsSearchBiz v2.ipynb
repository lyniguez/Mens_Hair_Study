# %%
# Dependencies
import pandas as pd
import numpy as np
from numpy import nan as Nan
import requests
import json
import re

# Google developer API key
gkey = "AIzaSyDbW3R50-rJm1kDS5AcAfMd0gSrpRB9wko"

# %%
gsearch = input("What would you like to search?")
# Out:
# What would you like to search?men's hair

# %%
gsearch
# Out:
# "men's hair"

# %% [markdown]
# # find the closest restaurant of each type to coordinates
#
# base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# params = {
#     "location": "33.66946, -117.82311",  # Irvine coords,
#     "rankby":"distance",
#     "type":"hair_care",
#     "key": gkey
# }
#
# response = requests.get(base_url, params)
# print(response.url)

# %%
# find the closest restaurant of each type to coordinates

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "location": "33.66946, -117.82311",  # Irvine coords,
    "rankby":"distance",
    "type":"hair_care",
    "keyword": gsearch,
    "key": gkey
}

 # assemble url and make API request
print(f"Retrieving Results for: {gsearch}.")
response = requests.get(base_url, params=params)
url = response.url
print(response.url)
print("============================================")
# Out:
# Retrieving Results for: men's hair.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.66946%2C+-117.82311&rankby=distance&type=hair_care&keyword=men%27s+hair&key=AIzaSyDbW3R50-rJm1kDS5AcAfMd0gSrpRB9wko
# ============================================

# %%
df = json.loads(requests.get(url).text)
list(df.keys())
# Out:
# ['html_attributions', 'next_page_token', 'results', 'status']

# %%
googleDF = pd.DataFrame(df["results"])

# %%
googleDF
# Out:
#                                              geometry  \
# 0   {'location': {'lat': 33.676153, 'lng': -117.85...
# 1   {'location': {'lat': 33.6710241, 'lng': -117.7...
# 2   {'location': {'lat': 33.7005489, 'lng': -117.8...
# 3   {'location': {'lat': 33.6869987, 'lng': -117.8...
# 4   {'location': {'lat': 33.6965972, 'lng': -117.7...
# 5   {'location': {'lat': 33.6661324, 'lng': -117.8...
# 6   {'location': {'lat': 33.658796, 'lng': -117.87...
# 7   {'location': {'lat': 33.6389961, 'lng': -117.8...
# 8   {'location': {'lat': 33.66856900000001, 'lng':...
# 9   {'location': {'lat': 33.6903685, 'lng': -117.8...
# 10  {'location': {'lat': 33.6543404, 'lng': -117.7...
# 11  {'location': {'lat': 33.62994490000001, 'lng':...
# 12  {'location': {'lat': 33.6415245, 'lng': -117.9...
# 13  {'location': {'lat': 33.6296166, 'lng': -117.7...
# 14  {'location': {'lat': 33.6170092, 'lng': -117.9...
# 15  {'location': {'lat': 33.6181774, 'lng': -117.7...
# 16  {'location': {'lat': 33.7818444, 'lng': -117.8...
# 17  {'location': {'lat': 33.7907442, 'lng': -117.8...
# 18  {'location': {'lat': 33.5687411, 'lng': -117.7...
# 19  {'location': {'lat': 33.7298, 'lng': -117.9811...
#
#                                                  icon  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                           id  \
# 0   0cd8fedf6e2b5e7a797b03f899cfdb84b0a9d620
# 1   8f50c132176ccbabb27a2d6403cf5a5b632dcc25
# 2   29f69d8dbe9d3663c04112e68698c787a0ad81d4
# 3   5e758d05b818b0267fee5898fe563def82bedba9
# 4   d84cc3362a141ed1d556442b3a583e9a76209fa0
# 5   98cf34ae77491ce6f277518b0f1321dc99c603e7
# 6   6cd1d58c1b0659a0ca5d392ef0ecc0bb728d3be8
# 7   ecd5c348e0c511bdac1a35f0a5eb4e36619e235d
# 8   110d778de41f8d56700ff5c9b974fc4ea597c745
# 9   543782fec804c61c7f4d9e7c1a95adba00a492d3
# 10  1ad68b00c7b59513efdea64b4ac2f19f467ec067
# 11  cc824d775bee3916008f7acea82704c7ada8186d
# 12  4a4d768b658cb86e5c6cdb0f0cb1f22ab6c461e2
# 13  55f504e2cb6c3f9b0701e3dbfad79476de3341c7
# 14  877d52c663a95b77baeddddef5187e965e6399fc
# 15  f6990033457842ffae91298d41492581a7e0c778
# 16  bd16b82583c1ce0224426a32eb8e2c244e8e4158
# 17  896344f9d83bc5c85ee30c31eaa381d9d0ca0a0b
# 18  f9d8209b1416a71f7070c5312cbb68b60cc232f4
# 19  a1c82ae2f07a0d67eabc523f7bfd7ded6aea5012
#
#                                                  name  \
# 0                                    KEMPT Men's Hair
# 1                      Roosters Men's Grooming Center
# 2                      Sport Clips Haircuts of Tustin
# 3   Irvine's PRO-IMAGES Haircuts and Color - Men/W...
# 4                               EM20 Men's Hair Salon
# 5         Barbery Coast Hair Studio: Haircuts for Men
# 6                                    PRESS Men's Hair
# 7                                          A&O Salons
# 8                                   Alire Hair Design
# 9                 18|8 Fine Men's Salons - Costa Mesa
# 10                                      metro FOR MEN
# 11                           Mr J's Mens Hair Styling
# 12  18|8 Fine Men's Salons - Costa Mesa On Newport...
# 13                            First Class Men's Salon
# 14                     Californian Men's Hair Designs
# 15               18|8 Fine Men's Salons - Lake Forest
# 16                                          Hair Club
# 17                              Nineson's Men Haircut
# 18                Refine Men's Salon of Laguna Niguel
# 19  CMK Barber - Men Haircuts & Hairstyles & Fade ...
#
#                               opening_hours  \
# 0   {'open_now': False, 'weekday_text': []}
# 1   {'open_now': False, 'weekday_text': []}
# 2    {'open_now': True, 'weekday_text': []}
# 3   {'open_now': False, 'weekday_text': []}
# 4   {'open_now': False, 'weekday_text': []}
# 5   {'open_now': False, 'weekday_text': []}
# 6    {'open_now': True, 'weekday_text': []}
# 7    {'open_now': True, 'weekday_text': []}
# 8   {'open_now': False, 'weekday_text': []}
# 9    {'open_now': True, 'weekday_text': []}
# 10  {'open_now': False, 'weekday_text': []}
# 11                                      NaN
# 12   {'open_now': True, 'weekday_text': []}
# 13  {'open_now': False, 'weekday_text': []}
# 14                                      NaN
# 15   {'open_now': True, 'weekday_text': []}
# 16  {'open_now': False, 'weekday_text': []}
# 17  {'open_now': False, 'weekday_text': []}
# 18   {'open_now': True, 'weekday_text': []}
# 19  {'open_now': False, 'weekday_text': []}
#
#                                                photos  \
# 0   [{'height': 4752, 'html_attributions': ['<a hr...
# 1   [{'height': 1365, 'html_attributions': ['<a hr...
# 2   [{'height': 3888, 'html_attributions': ['<a hr...
# 3   [{'height': 1600, 'html_attributions': ['<a hr...
# 4   [{'height': 2448, 'html_attributions': ['<a hr...
# 5   [{'height': 662, 'html_attributions': ['<a hre...
# 6   [{'height': 1359, 'html_attributions': ['<a hr...
# 7   [{'height': 480, 'html_attributions': ['<a hre...
# 8   [{'height': 1536, 'html_attributions': ['<a hr...
# 9   [{'height': 900, 'html_attributions': ['<a hre...
# 10  [{'height': 1365, 'html_attributions': ['<a hr...
# 11                                                NaN
# 12  [{'height': 615, 'html_attributions': ['<a hre...
# 13  [{'height': 2448, 'html_attributions': ['<a hr...
# 14                                                NaN
# 15  [{'height': 1519, 'html_attributions': ['<a hr...
# 16  [{'height': 1920, 'html_attributions': ['<a hr...
# 17  [{'height': 3024, 'html_attributions': ['<a hr...
# 18  [{'height': 3456, 'html_attributions': ['<a hr...
# 19  [{'height': 1536, 'html_attributions': ['<a hr...
#
#                        place_id  rating  \
# 0   ChIJcRWHm0_e3IAR84YMUQl4LYc     5.0
# 1   ChIJH3NQMaHd3IARtIRNtIlfm_g     4.4
# 2   ChIJ68kXdR_c3IARVzIRjlsOsIg     3.2
# 3   ChIJR8L2Auve3IAR7wXzrdceDmI     NaN
# 4   ChIJAQDATkTc3IARhhS7rQpR_pY     5.0
# 5   ChIJ01EbOlje3IARhfhl1vGxlIs     4.9
# 6   ChIJ-2A5eVHe3IAR5EDdwKciFhY     4.7
# 7   ChIJ_ayipzze3IARZ0wcH3Mw4O4     4.4
# 8   ChIJ2STGTWrd3IARwTsBMAggQXc     5.0
# 9   ChIJSd2NoCbf3IARKu3dUHEsloE     4.8
# 10  ChIJfb8DTP7n3IAR5fF7ksomxM0     4.6
# 11  ChIJ0W3ZX-7f3IARLqar2CUUsoU     NaN
# 12  ChIJkTnbOYnf3IAR4Cs82mAY_YY     4.8
# 13  ChIJ41oRCWbo3IARhRfLFqOyaAI     5.0
# 14  ChIJJdX51gYg3YARA9KaEKVaYxo     NaN
# 15  ChIJ80heE_ro3IARPl5FlZJLIVM     4.9
# 16  ChIJTcHnscTZ3IARhDEJDtC1OC4     4.2
# 17  ChIJ6-ronPnZ3IAR7PV1bGRas1I     4.6
# 18  ChIJdTht2Tvv3IARdRj3cZxb1qc     4.7
# 19  ChIJ68SqUVAm3YAREAszembmtIc     4.8
#
#                                             reference   scope  \
# 0   CmRbAAAAEmPT_TK8Cc9fFNs_ScD7WMgcWJCkDN7kzsQVL6...  GOOGLE
# 1   CmRbAAAAiktT6AXSTsZqaA14QytMueQ79wfxvh3xJCcc29...  GOOGLE
# 2   CmRbAAAAggLgRXb5l-qR0iOOdR0O4lLBeGjlxZVLoheQtT...  GOOGLE
# 3   CmRbAAAAYzhj4y-RAmoV6LKMbUegX3dFjyqwtjgWmCv3xN...  GOOGLE
# 4   CmRbAAAA0vfPSLl-SYjrkLKwnmbzIbf9wvKPLn2YTrBaZP...  GOOGLE
# 5   CmRbAAAAZgCMJiHuLd5yL0X_cqOxpJACkH6wCFpBcnLZxe...  GOOGLE
# 6   CmRbAAAAEzkaMY-d-Go9xlsQM2IoUDw9qLuGCX4OPuzAtr...  GOOGLE
# 7   CmRbAAAA-BsHjDQ5vy06QL82W4EAcsXtqBNAWQLUPWgS67...  GOOGLE
# 8   CmRbAAAAg0R7XN0X8dUAkadUJ2x1urbeyohSYEQ7z_m-Fu...  GOOGLE
# 9   CmRbAAAA8e5-_X6Q21S_nVs5GZypQzytBf3iHy0_XEO2mN...  GOOGLE
# 10  CmRbAAAA_loZyfGSIPgp3hJlemOGPPdh_xWhEbImbzrcNT...  GOOGLE
# 11  CmRbAAAAe_e--X2h0Nuz18sfhU4K0Sn-1aGElEpGyEYOBp...  GOOGLE
# 12  CmRbAAAAaJR-bEgH0OaZDS8fM5ojtteCTor-dPEEx-23MV...  GOOGLE
# 13  CmRbAAAA9s-5D4gAbyr6l1YoQgtuhWoqtBy75BwNQs79Cx...  GOOGLE
# 14  CmRbAAAAVmVhqzJY5ruSM6rd3nrbWwlfPID37xFosIU-Qc...  GOOGLE
# 15  CmRbAAAAhN1MXuYw4TEBVvxTr3Aq72Zd2wd3WXDJcmjxav...  GOOGLE
# 16  CmRbAAAAEVwOnJnOJN_rqDAa4NE7LsTRFS0FYiDOGvTJjF...  GOOGLE
# 17  CmRbAAAAkxsaiEZv7zN_Tg2QBf0hy769g4C8yOFqteec9d...  GOOGLE
# 18  CmRbAAAAT9ahndw01bVqA2DLZYV69RIY2oaom5DP9mIB9f...  GOOGLE
# 19  CmRbAAAAl-_QPJpYYMheY23mQpe4ye5goGeAOBJTk0IkuG...  GOOGLE
#
#                                                 types  \
# 0       [hair_care, point_of_interest, establishment]
# 1   [hair_care, health, point_of_interest, establi...
# 2   [hair_care, health, point_of_interest, establi...
# 3   [beauty_salon, hair_care, point_of_interest, e...
# 4   [hair_care, health, point_of_interest, establi...
# 5   [beauty_salon, hair_care, health, point_of_int...
# 6   [beauty_salon, hair_care, spa, health, point_o...
# 7   [beauty_salon, hair_care, health, point_of_int...
# 8       [hair_care, point_of_interest, establishment]
# 9   [beauty_salon, hair_care, health, point_of_int...
# 10  [beauty_salon, hair_care, spa, health, point_o...
# 11  [hair_care, health, point_of_interest, establi...
# 12  [hair_care, health, point_of_interest, establi...
# 13  [beauty_salon, hair_care, health, point_of_int...
# 14  [hair_care, health, point_of_interest, establi...
# 15  [beauty_salon, hair_care, store, health, point...
# 16  [beauty_salon, hair_care, spa, health, point_o...
# 17  [hair_care, health, point_of_interest, establi...
# 18  [beauty_salon, hair_care, health, point_of_int...
# 19  [beauty_salon, hair_care, health, point_of_int...
#
#                                              vicinity
# 0                   2222 Michelson Dr Ste 224, Irvine
# 1                             5405 Alton Pkwy, Irvine
# 2                               2318 Park Ave, Tustin
# 3                          18011 Sky Park Cir, Irvine
# 4                        15333 Culver Dr #200, Irvine
# 5                  4255 Martingale Way, Newport Beach
# 6             0789, 2300 SE Bristol St, Newport Beach
# 7                       1312 Bison Ave, Newport Beach
# 8                       6640 Irvine Center Dr, Irvine
# 9                        650 Anton Blvd f, Costa Mesa
# 10                           15382 Alton Pkwy, Irvine
# 11                       440 E 17th St #1, Costa Mesa
# 12        1835 Newport Blvd., Suite D-150, Costa Mesa
# 13            23600 Rockfield Blvd 3 A-B, Lake Forest
# 14                    3355 Via Lido #B, Newport Beach
# 15  The Orchard Shopping Center, 23626 El Toro Roa...
# 16                 431 S Batavia St Suite 201, Orange
# 17                          260 N Tustin St i, Orange
# 18         3636, 27241 La Paz Rd ste a, Laguna Niguel
# 19                 8452 Edinger Ave, Huntington Beach

# %%
googleDF = googleDF[['geometry','name','rating','types','vicinity']]

# %%
googleDF.columns = ['Geometry','Business Name','Rating','Business Types','Address']

# %%
googleDF.to_csv(f'../data/{gsearch}_google.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-6b6f6c68453c> in <module>()
# ----> 1 googleDF.to_csv(f'../data/{gsearch}_google.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1401                                      doublequote=doublequote,
#    1402                                      escapechar=escapechar, decimal=decimal)
# -> 1403         formatter.save()
#    1404
#    1405         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in save(self)
#    1575             f, handles = _get_handle(self.path_or_buf, self.mode,
#    1576                                      encoding=self.encoding,
# -> 1577                                      compression=self.compression)
#    1578             close = True
#    1579
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     383         elif is_text:
#     384             # Python 3 and no explicit encoding
# --> 385             f = open(path_or_buf, mode, errors='replace')
#     386         else:
#     387             # Python 3 and binary mode
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/_google.csv'

# %%
googleDF.head()

# %%
latlong = googleDF['Geometry']

# %%
location = []

for i in latlong:
    location.append(i['location'])

# %%
gDF = pd.DataFrame(location)
gDF
# Out:
#           lat         lng
# 0   33.664119 -117.827081
# 1   33.675442 -117.829669
# 2   33.676124 -117.832794
# 3   33.658947 -117.828166
# 4   33.677598 -117.833026
# 5   33.682375 -117.811590
# 6   33.682539 -117.811843
# 7   33.682469 -117.811711
# 8   33.680656 -117.838000
# 9   33.684403 -117.812357
# 10  33.684518 -117.812515
# 11  33.672531 -117.843867
# 12  33.685042 -117.810495
# 13  33.681423 -117.805323
# 14  33.681261 -117.805054
# 15  33.659214 -117.803562
# 16  33.682193 -117.840649
# 17  33.659297 -117.803202
# 18  33.680700 -117.803782
# 19  33.672298 -117.846442

# %%
googleLatLong = googleDF.join(gDF)
googleLatLong
# Out:
#                                              Geometry  \
# 0   {'location': {'lat': 33.6725307, 'lng': -117.8...
# 1   {'location': {'lat': 33.6850424, 'lng': -117.8...
# 2   {'location': {'lat': 33.6806996, 'lng': -117.8...
# 3   {'location': {'lat': 33.6976351, 'lng': -117.8...
# 4   {'location': {'lat': 33.6710241, 'lng': -117.7...
# 5   {'location': {'lat': 33.6869575, 'lng': -117.8...
# 6   {'location': {'lat': 33.6623501, 'lng': -117.8...
# 7   {'location': {'lat': 33.658796, 'lng': -117.87...
# 8   {'location': {'lat': 33.699564, 'lng': -117.86...
# 9   {'location': {'lat': 33.6584767, 'lng': -117.8...
# 10  {'location': {'lat': 33.7333396, 'lng': -117.8...
# 11  {'location': {'lat': 33.723578, 'lng': -117.86...
# 12  {'location': {'lat': 33.7346001, 'lng': -117.8...
# 13  {'location': {'lat': 33.6556174, 'lng': -117.9...
# 14  {'location': {'lat': 33.7283927, 'lng': -117.8...
# 15  {'location': {'lat': 33.7168672, 'lng': -117.8...
# 16  {'location': {'lat': 33.611603, 'lng': -117.87...
# 17  {'location': {'lat': 33.7405211, 'lng': -117.8...
# 18  {'location': {'lat': 33.7453127, 'lng': -117.8...
# 19  {'location': {'lat': 33.745364, 'lng': -117.81...
#
#                                         Business Name  Rating  \
# 0                              Park Place Barber Shop     4.6
# 1                               Floyd's 99 Barbershop     3.9
# 2   Stonecreek Plaza Barber Shop (inside H&R Block...     4.9
# 3                              Black Steel Barbershop     4.0
# 4                      Roosters Men's Grooming Center     4.4
# 5                        Creations Salon & Barbershop     4.7
# 6                         The beautician & the barber     3.0
# 7                                    PRESS Men's Hair     4.7
# 8                             South Coast Barber Shop     4.3
# 9                               True Blue Barber Shop     4.3
# 10                                   JB's Barber Shop     2.7
# 11                             Prime Time Barber Shop     3.9
# 12                                  Woori Barber Shop     NaN
# 13                         Aces And Eights Barbershop     5.0
# 14                               Ringside Barber Shop     4.6
# 15                        Faded Barber Shop Santa Ana     4.5
# 16                          Newport Beach Barber Shop     5.0
# 17                               Justin's Barber Shop     4.6
# 18                                Louie's Barber Shop     4.6
# 19                                      i Barber Shop     4.2
#
#                                        Business Types  \
# 0   [hair_care, health, point_of_interest, establi...
# 1   [beauty_salon, hair_care, health, point_of_int...
# 2   [hair_care, health, point_of_interest, establi...
# 3   [hair_care, health, point_of_interest, establi...
# 4   [hair_care, health, point_of_interest, establi...
# 5   [hair_care, health, point_of_interest, establi...
# 6   [hair_care, health, point_of_interest, establi...
# 7   [beauty_salon, hair_care, spa, health, point_o...
# 8   [hair_care, health, point_of_interest, establi...
# 9   [hair_care, health, point_of_interest, establi...
# 10  [hair_care, health, point_of_interest, establi...
# 11  [hair_care, health, point_of_interest, establi...
# 12  [hair_care, health, point_of_interest, establi...
# 13  [hair_care, health, point_of_interest, establi...
# 14  [hair_care, health, point_of_interest, establi...
# 15  [hair_care, health, point_of_interest, establi...
# 16  [hair_care, health, point_of_interest, establi...
# 17  [hair_care, health, point_of_interest, establi...
# 18  [hair_care, health, point_of_interest, establi...
# 19  [hair_care, health, point_of_interest, establi...
#
#                                     Address        lat         lng
# 0           3333 Michelson Dr # 110, Irvine  33.672531 -117.843867
# 1              3972 Barranca Pkwy H, Irvine  33.685042 -117.810495
# 2           4330 Barranca Pkwy #105, Irvine  33.680700 -117.803782
# 3                 2493 Park Ave #28, Tustin  33.697635 -117.827587
# 4                   5405 Alton Pkwy, Irvine  33.671024 -117.788047
# 5                     17779 Main St, Irvine  33.686957 -117.858372
# 6           3723 Birch St #5, Newport Beach  33.662350 -117.872744
# 7   0789, 2300 SE Bristol St, Newport Beach  33.658796 -117.871888
# 8           118 W MacArthur Blvd, Santa Ana  33.699564 -117.869135
# 9               2675 Irvine Ave, Costa Mesa  33.658477 -117.885429
# 10                14435 Newport Ave, Tustin  33.733340 -117.827691
# 11                1911 S Main St, Santa Ana  33.723578 -117.867624
# 12               13846 Red Hill Ave, Tustin  33.734600 -117.812734
# 13   2346, ste b2, Newport Blvd, Costa Mesa  33.655617 -117.903723
# 14              1414 S Main St A, Santa Ana  33.728393 -117.868035
# 15             2222 S Bristol St, Santa Ana  33.716867 -117.885878
# 16          1367 Avocado Ave, Newport Beach  33.611603 -117.871701
# 17              13762 Newport Ave b, Tustin  33.740521 -117.819439
# 18                   414 E First St, Tustin  33.745313 -117.819752
# 19                   622 E First St, Tustin  33.745364 -117.817072

# %%
googleLatLong = googleLatLong[['lat','lng','Business Name','Rating','Business Types','Address']]

# %%
googleLatLong.columns = ['Latitude','Longitude','Business Name','Rating','Business Types','Address']

# %%
googleLatLong.to_csv(f'../data/{gsearch}_googleLatLong.csv')

# %%
googleLatLong
# Out:
#      Latitude   Longitude                                      Business Name  \
# 0   33.672531 -117.843867                             Park Place Barber Shop
# 1   33.685042 -117.810495                              Floyd's 99 Barbershop
# 2   33.680700 -117.803782  Stonecreek Plaza Barber Shop (inside H&R Block...
# 3   33.697635 -117.827587                             Black Steel Barbershop
# 4   33.671024 -117.788047                     Roosters Men's Grooming Center
# 5   33.686957 -117.858372                       Creations Salon & Barbershop
# 6   33.662350 -117.872744                        The beautician & the barber
# 7   33.658796 -117.871888                                   PRESS Men's Hair
# 8   33.699564 -117.869135                            South Coast Barber Shop
# 9   33.658477 -117.885429                              True Blue Barber Shop
# 10  33.733340 -117.827691                                   JB's Barber Shop
# 11  33.723578 -117.867624                             Prime Time Barber Shop
# 12  33.734600 -117.812734                                  Woori Barber Shop
# 13  33.655617 -117.903723                         Aces And Eights Barbershop
# 14  33.728393 -117.868035                               Ringside Barber Shop
# 15  33.716867 -117.885878                        Faded Barber Shop Santa Ana
# 16  33.611603 -117.871701                          Newport Beach Barber Shop
# 17  33.740521 -117.819439                               Justin's Barber Shop
# 18  33.745313 -117.819752                                Louie's Barber Shop
# 19  33.745364 -117.817072                                      i Barber Shop
#
#     Rating                                     Business Types  \
# 0      4.6  [hair_care, health, point_of_interest, establi...
# 1      3.9  [beauty_salon, hair_care, health, point_of_int...
# 2      4.9  [hair_care, health, point_of_interest, establi...
# 3      4.0  [hair_care, health, point_of_interest, establi...
# 4      4.4  [hair_care, health, point_of_interest, establi...
# 5      4.7  [hair_care, health, point_of_interest, establi...
# 6      3.0  [hair_care, health, point_of_interest, establi...
# 7      4.7  [beauty_salon, hair_care, spa, health, point_o...
# 8      4.3  [hair_care, health, point_of_interest, establi...
# 9      4.3  [hair_care, health, point_of_interest, establi...
# 10     2.7  [hair_care, health, point_of_interest, establi...
# 11     3.9  [hair_care, health, point_of_interest, establi...
# 12     NaN  [hair_care, health, point_of_interest, establi...
# 13     5.0  [hair_care, health, point_of_interest, establi...
# 14     4.6  [hair_care, health, point_of_interest, establi...
# 15     4.5  [hair_care, health, point_of_interest, establi...
# 16     5.0  [hair_care, health, point_of_interest, establi...
# 17     4.6  [hair_care, health, point_of_interest, establi...
# 18     4.6  [hair_care, health, point_of_interest, establi...
# 19     4.2  [hair_care, health, point_of_interest, establi...
#
#                                     Address
# 0           3333 Michelson Dr # 110, Irvine
# 1              3972 Barranca Pkwy H, Irvine
# 2           4330 Barranca Pkwy #105, Irvine
# 3                 2493 Park Ave #28, Tustin
# 4                   5405 Alton Pkwy, Irvine
# 5                     17779 Main St, Irvine
# 6           3723 Birch St #5, Newport Beach
# 7   0789, 2300 SE Bristol St, Newport Beach
# 8           118 W MacArthur Blvd, Santa Ana
# 9               2675 Irvine Ave, Costa Mesa
# 10                14435 Newport Ave, Tustin
# 11                1911 S Main St, Santa Ana
# 12               13846 Red Hill Ave, Tustin
# 13   2346, ste b2, Newport Blvd, Costa Mesa
# 14              1414 S Main St A, Santa Ana
# 15             2222 S Bristol St, Santa Ana
# 16          1367 Avocado Ave, Newport Beach
# 17              13762 Newport Ave b, Tustin
# 18                   414 E First St, Tustin
# 19                   622 E First St, Tustin
